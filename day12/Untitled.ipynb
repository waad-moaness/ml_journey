# %%
import pandas as pd

# %%
movie_df = pd.read_csv('IMDb movies.csv/IMDb movies.csv', low_memory=False)

# %%
rating_df = pd.read_csv('IMDb ratings.csv/IMDb ratings.csv',low_memory= False)

# %%
movie_df
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
movie_df = movie_df[['imdb_title_id', 'title', 'year', 'genre', 'country']]

# %%
movie_df
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# ...

# %%
rating_df = rating_df[['imdb_title_id', 'total_votes', 'mean_vote']]
rating_df
# Out:
#       imdb_title_id  total_votes  mean_vote
# 0         tt0000009          154        5.9
# 1         tt0000574          589        6.3
# 2         tt0001892          188        6.0
# 3         tt0002101          446        5.3
# 4         tt0002130         2237        6.9
# ...             ...          ...        ...
# 85850     tt9908390          398        5.5
# 85851     tt9911196          724        7.9
# 85852     tt9911774          265        7.8
# 85853     tt9914286          194        9.4
# 85854     tt9914942          102        6.8
#
# [85855 rows x 3 columns]

# %%
concate_movie_df= movie_df.sample(frac=0.5)

# %%
concate_movie_df.shape
# Out:
# (42928, 5)

# %%
pd.concat([movie_df,concate_movie_df])
# Out:
#       imdb_title_id                            title  year  \
# 0         tt0000009                       Miss Jerry  1894
# 1         tt0000574      The Story of the Kelly Gang  1906
# 2         tt0001892                   Den sorte drøm  1911
# 3         tt0002101                        Cleopatra  1912
# 4         tt0002130                        L'Inferno  1911
# ...             ...                              ...   ...
# 67268     tt2428612  House of Horrors: Gates of Hell  2012
# 11602     tt0057415                    A Place to Go  1963
# 14030     tt0064498            Isten hozta örnagy úr  1969
# 35728     tt0195857                              Kin  2000
# 48617     tt0479651                     Dasavatharam  2008
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# ...

# %%
movie_df.shape
# Out:
# (85855, 5)

# %%
movie_df.set_index('imdb_title_id', inplace= True)
rating_df.set_index('imdb_title_id', inplace= True)
#the error cuz i rerun it again but it worked just fine
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4993/2002287669.py in ?()
# ----> 1 movie_df.set_index('imdb_title_id', inplace= True)
#       2 rating_df.set_index('imdb_title_id', inplace= True)
#       3 concated_df= pd.concat([movie_df,rating_df ], axis=1)
#
# ~/Documents/my_ml_project/myenv/lib64/python3.13/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['imdb_title_id'] are in the columns"

# %%
concated_df= pd.concat([movie_df,rating_df ], axis=1)

# %%
concated_df
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country  total_votes  \
# imdb_title_id
# tt0000009                        Romance               USA          154
# tt0000574        Biography, Crime, Drama         Australia          589
# tt0001892                          Drama  Germany, Denmark          188
# ...
