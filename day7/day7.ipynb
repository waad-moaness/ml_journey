# %%
import pandas as pd 
df = pd.read_csv("laptop_price.csv", encoding='latin1')

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
# to find which row has a value of ... in the df then return a boolean series 
df.Company == "Apple"
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
# filter df based on condition
# df[df.Company == "Apple"]
df[df.Company == "Apple"].value_counts('Company')  # to count the values of a spicific row
# Out:
# Company
# Apple    21
# Name: count, dtype: int64

# %%
df[df.Company != 'HP'].value_counts('Company')
# Out:
# Company
# Lenovo       297
# Dell         297
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Google         3
# LG             3
# Fujitsu        3
# Huawei         2
# Name: count, dtype: int64

# %%
df.Product[df.Price_euros > 2000]
# Out:
# 3         MacBook Pro
# 6         MacBook Pro
# 12        MacBook Pro
# 17        MacBook Pro
# 58         GS73VR 7RG
#             ...
# 1203           XPS 13
# 1209        Rog Strix
# 1231        Blade Pro
# 1236    EliteBook 840
# 1247      Rog GL502VS
# Name: Product, Length: 137, dtype: object

# %%
# create a new column based on the screan size 
import numpy as np # so we can use where() 

df['Screen_size'] = np.where(df.Inches > 13 , 'Big Screen', 'Small Screen')

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.value_counts('Screen_size')
# Out:
# Screen_size
# Big Screen      1213
# Small Screen      90
# Name: count, dtype: int64

# %%
# create a new column based on multiple condition select()
conditions=[
    df.Price_euros >=  3000,
    ( (df.Price_euros >= 2000) &  (df.Price_euros < 3000)),
     df.Price_euros < 2000
]
values = ['expensive' , 'mid', 'cheap']

# %%
df['price_tiers'] = np.select(conditions, values, default='unknown')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
#  13  Screen_size       1303 non-null   object
#  14  price_tiers       1303 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 152.8+ KB

# %%
# filter multiple conditions using isin()
df[(df.Company.isin(["Apple","HP"])) & (df.TypeName.isin(["Ultrabook","Notebook"]))].value_counts(['Company', 'TypeName'])
# Out:
# Company  TypeName
# HP       Notebook     184
#          Ultrabook     36
# Apple    Ultrabook     21
# Name: count, dtype: int64

# %%
# sort df by company and price
df2 = df.sort_values(['Company', 'Price_euros'])
df2.Company.value_counts()
df2[df2.duplicated("Company", keep = "first")] #show duplecated observations execluding first dup 
# keep last returns all dups execluding last dup , keep = False return all dups in the data
# to show data with no dups use the ~
df2[~df2.duplicated("Company", keep = "first")] [["Company","Price_euros"]]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
# if we check now we will see no dups
df2[~df2.duplicated("Company", keep = "first")]["Company"].value_counts()
# Out:
# Company
# Acer         1
# Apple        1
# Asus         1
# Chuwi        1
# Dell         1
# Fujitsu      1
# Google       1
# HP           1
# Huawei       1
# LG           1
# Lenovo       1
# MSI          1
# Mediacom     1
# Microsoft    1
# Razer        1
# Samsung      1
# Toshiba      1
# Vero         1
# Xiaomi       1
# Name: count, dtype: int64

# %%
# find the biggst and the smallest screen sizes in each company 
# 1 sort values 
df.sort_values(['Company','Inches'] , inplace = True)
df[['Company','Inches']]
# Out:
#      Company  Inches
# 319     Acer    11.6
# 461     Acer    11.6
# 560     Acer    11.6
# 619     Acer    11.6
# 695     Acer    11.6
# ...      ...     ...
# 1041    Vero    14.0
# 192   Xiaomi    13.3
# 877   Xiaomi    13.3
# 184   Xiaomi    15.6
# 514   Xiaomi    15.6
#
# [1303 rows x 2 columns]

# %%
# 2 drop dups excluding the biggst
df.drop_duplicates('Company', keep = 'last')[['Company','Inches']]
# Out:
#         Company  Inches
# 1216       Acer    17.3
# 17        Apple    15.4
# 1256       Asus    17.3
# 483       Chuwi    15.6
# 1243       Dell    17.3
# 983     Fujitsu    15.6
# 762      Google    12.3
# 1136         HP    17.3
# 214      Huawei    13.0
# 905          LG    15.6
# 1217     Lenovo    17.3
# 177         MSI    18.4
# 718    Mediacom    14.0
# 670   Microsoft    13.5
# 830       Razer    17.3
# 593     Samsung    15.6
# 1042    Toshiba    15.6
# 1041       Vero    14.0
# 514      Xiaomi    15.6

# %%
# 3 drop dups excluding the smallest
df.drop_duplicates('Company', keep = 'first', ignore_index= True)[['Company','Inches']]
# Out:
#       Company  Inches
# 0        Acer    11.6
# 1       Apple    11.6
# 2        Asus    11.6
# 3       Chuwi    12.3
# 4        Dell    11.6
# 5     Fujitsu    15.6
# 6      Google    12.3
# 7          HP    11.6
# 8      Huawei    13.0
# 9          LG    14.0
# 10     Lenovo    10.1
# 11        MSI    14.0
# 12   Mediacom    11.6
# 13  Microsoft    13.5
# 14      Razer    12.5
# 15    Samsung    11.6
# 16    Toshiba    12.5
# 17       Vero    13.3
# 18     Xiaomi    13.3

# %%
df.Company.unique() # return unique values
# Out:
# array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#        'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
#        'Razer', 'Samsung', 'Toshiba', 'Vero', 'Xiaomi'], dtype=object)

# %%
len(df.Company.unique()) #number of values
# Out:
# 19

# %%
# nunique return the num of unique values samr as len()
df.Company.nunique()
# Out:
# 19
